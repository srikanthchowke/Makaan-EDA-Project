# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("csv_after_cleaning_for_data_analysis_and_viz.csv")
df
# Out:
#       Unnamed: 0                                          BUILDERS  SIZE  \
# 0              0     Ashoka Builders India Private LimitedBUILDER0     3
# 1              1                     Sunyuga Infra Pvt LtdBUILDER0     4
# 2              2  Raghuram Pradeep Constructions India LLPBUILDER0     4
# 3              3                     Kalyan Infra ProjectsBUILDER0     3
# 4              4                          Risinia BuildersBUILDER0     2
# ...          ...                                               ...   ...
# 1782        1782       Full Basket property services Pvt ltdAGENT0     2
# 1783        1783       Full Basket property services Pvt ltdAGENT0     2
# 1784        1784       Full Basket property services Pvt ltdAGENT0     2
# 1785        1785       Full Basket property services Pvt ltdAGENT0     2
# 1786        1786       Full Basket property services Pvt ltdAGENT0     2
#
#      PROPERTY_TYPE   PROPERTY_ADDRESS       CITY  AREA  RATE_SQFT   PRICE  \
# ...

# %%
df=df.drop(columns=["Unnamed: 0"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1787 entries, 0 to 1786
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   BUILDERS             1787 non-null   object
#  1   SIZE                 1787 non-null   int64
#  2   PROPERTY_TYPE        1787 non-null   object
#  3   PROPERTY_ADDRESS     1787 non-null   object
#  4   CITY                 1787 non-null   object
#  5   AREA                 1787 non-null   int64
#  6   RATE_SQFT            1787 non-null   int64
#  7   PRICE                1787 non-null   float64
#  8   CONSTRUCTION_STATUS  1787 non-null   object
#  9   LISTED_BY            1787 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 139.7+ KB

# %% [markdown]
# # univariate analysis

# %%
#1.AREA

df["AREA"].describe()      #description of area
# Out:
# count    1787.000000
# mean     2034.242306
# std      1534.944001
# min       309.000000
# 25%      1068.000000
# 50%      1545.000000
# 75%      2253.000000
# max      7674.000000
# Name: AREA, dtype: float64

# %%
plt.hist(df["AREA"],bins=10,color="BLUE",range=(309.000000,7674.000000))    #EXCLUDING OUTLIERS BY FIXING RANGE
plt.title('DISTRIBUTION OF TOTAL FLOOR AREA')
plt.xlabel('AREA IN SQUARE FEET')
plt.ylabel('FREQUENCY')
plt.show()

# %%
#2.rate_sqft

df["RATE_SQFT"].describe()
# Out:
# count      1787.000000
# mean      16593.923335
# std       20750.632306
# min           0.000000
# 25%        5599.000000
# 50%        9000.000000
# 75%       20036.000000
# max      177670.000000
# Name: RATE_SQFT, dtype: float64

# %%
plt.hist(df["RATE_SQFT"],bins=10,color="violet",range=(425.000000,20036.000000))    #EXCLUDING OUTLIERS BY FIXING RANGE
plt.title('DISTRIBUTION OF RATE_SQFT')
plt.xlabel('RATE PER SQUARE FEET')
plt.ylabel('FREQUENCY')
plt.show()

# %%
#3.price
df["PRICE"].describe()
# Out:
# count    1787.000000
# mean        4.924897
# std        11.866666
# min         0.059900
# 25%         0.770000
# 50%         1.380000
# 75%         3.895000
# max        99.890000
# Name: PRICE, dtype: float64

# %%
sns.violinplot(df["PRICE"],labels="PROPERTIES",color="yellow")    #EXCLUDING OUTLIERS BY FIXING RANGE
plt.title('DISTRIBUTION OF PROPERTY PRICE')
plt.xlabel('PROPERTY')
plt.ylabel('PRICES OF PROPERTIES IN CRORES')
plt.show()

# %%
#4.construction status
a=(len(df[df['CONSTRUCTION_STATUS']=='Under Construction'])/len(df['CONSTRUCTION_STATUS']))*100
b=(len(df[df['CONSTRUCTION_STATUS']=='Ready to move'])/len(df['CONSTRUCTION_STATUS']))*100
print("Under Construction:",a)
print("Ready to move:",b)
# Out:
# Under Construction: 58.92557358701735
# Ready to move: 41.07442641298265

# %%
labels=['Under Construction', 'Ready to move']
per = [a,b]
plt.pie(per,labels=labels,autopct='%0.2f%%')
plt.title("CONSTRUCTION STATUS IN PERCENTAGE",color='r')
plt.show()

# %%
#df['LISTED_BY'].replace(' â\x80§ AGENT', 'OWNER', inplace=True)

# %%
#5.LISTEBY

c=(len(df[df['LISTED_BY']=='BUILDER'])/len(df['LISTED_BY']))*100
d=(len(df[df['LISTED_BY']=='AGENT'])/len(df['LISTED_BY']))*100
e=(len(df[df['LISTED_BY']=='OWNER'])/len(df['LISTED_BY']))*100
print("BUILDER:",c)
print("AGENT:",d)
print("OWNER:",e)
# Out:
# BUILDER: 22.607722439843315
# AGENT: 47.50979294907666
# OWNER: 0.0

# %%
labels=['BUILDER','AGENT','OWNER']
per = [c,d,e]
plt.pie(per,labels=labels,autopct='%0.2f%%')
plt.title("PROPERTIES LISTED BY ",color='r')
plt.show()

# %%
#6.size

df["SIZE"].describe()
# Out:
# count    1787.000000
# mean        2.811975
# std         0.967797
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         8.000000
# Name: SIZE, dtype: float64

# %%
plt.hist(df["SIZE"],bins=10,color="r")    #EXCLUDING OUTLIERS BY FIXING RANGE
plt.title('DISTRIBUTION OF SIZES')
plt.xlabel('SIZE(BHK)')
plt.ylabel('FREQUENCY')
plt.show()

# %% [markdown]
# ## bivariate analysis

# %% [markdown]
# ## 1.Top 5 builders which have most properties listed within each city

# %%
df["BUILDERS"].replace("ProptigerAGENT0", "Proptiger", inplace=True)
df["BUILDERS"].replace("Prop UrbanAGENT4.5", "Prop Urban", inplace=True)
df["BUILDERS"].replace("NSR VenturesAGENT0", "NSR Ventures", inplace=True)
df["BUILDERS"].replace("Jhp InfraAGENT3.3", "ProptigerCity", inplace=True)
df["BUILDERS"].replace("Full Basket property services Pvt ltdAGENT0", "Full Basket property services Pvt", inplace=True)
df["BUILDERS"].replace("INSTAPROPAGENT0", "INSTAPROP", inplace=True)
df["BUILDERS"].replace("ARB HOMESAGENT0", "ARB HOMES", inplace=True)
df["BUILDERS"].replace("Jhp InfraAGENT3.3B Kumar and BrothersAGENT0", "Jhp Infra", inplace=True)
df["BUILDERS"].replace("Property GalleryAGENT0", "Property Gallery", inplace=True)
df["BUILDERS"].replace("Shourya InfratechAGENT4.7", "Shourya Infratech", inplace=True)
df["BUILDERS"].replace("Jagdamba AssociatesAGENT0", "Jagdamba Associates", inplace=True)
df["BUILDERS"].replace("gorkahpria associatesAGENT0", "gorkahpria associates", inplace=True)
df["BUILDERS"].replace("Hallmark BuildersBUILDER0", "Hallmark Builders", inplace=True)
df["BUILDERS"].replace("Salarpuria SattvaBUILDER0", "Salarpuria Sattva", inplace=True)
df["BUILDERS"].replace("Riddhi GroupBUILDER0", "Riddhi Group", inplace=True)
df["BUILDERS"].replace("GHR InfraBUILDER0", "GHR Infra", inplace=True)
df["BUILDERS"].replace("Sunyuga Infra Pvt LtdBUILDER0", "Sunyuga Infra Pvt Ltd", inplace=True)
df["BUILDERS"].replace("Space OneAGENT0", "Space One", inplace=True)
df["BUILDERS"].replace("Himanshu RangaAGENT0", "Himanshu Ranga", inplace=True)
df["BUILDERS"].replace("amitBUILDER0", "amit", inplace=True)
df["BUILDERS"].replace("ProptigerCity Expert â§ AGENT4.81 Rating", "ProptigerCity", inplace=True)

# %% [markdown]
# ## 2.How Avg property Rate per sqft vary within each city

# %%
data1=df.groupby('CITY')['RATE_SQFT'].mean()
data1
# Out:
# CITY
# Bangalore     5903.289474
# Chennai       6669.051672
# Delhi        35316.139726
# Hyderabad     7827.418367
# Mumbai       24448.070529
# Name: RATE_SQFT, dtype: float64

# %%
sns.boxplot(x=df["CITY"],y=df["RATE_SQFT"])
plt.show()

# %% [markdown]
# ## 3.trends of most common property types in different addresses within city

# %%
prop_trends=df.groupby(["CITY","PROPERTY_TYPE"])["PROPERTY_ADDRESS"].apply(lambda x: x.value_counts().sort_values(ascending=False).head(5))
prop_trends
# Out:
# CITY       PROPERTY_TYPE
# Bangalore  Apartment      Whitefield            52
#                           Kanakapura            47
#                           Subramanyapura        35
#                           Budigere              28
#                           Krishnarajapura       20
#            Independent    Ramamurthy             1
#                           Kammanahalli           1
#                           Kasturi                1
#                           OMBR                   1
#                           byatarayanapura        1
# Chennai    Apartment      Sholinganallur        85
#                           Oragadam              24
#                           Vadapalani            23
#                           Mugalivakkam          20
#                           Porur                 17
#            Independent    Chengalpattu           8
#                           Oragadam               2
#                           Maraimalai             1
# ...

# %%
prop_trends = prop_trends.reset_index()
plt.figure(figsize=(12, 6))

sns.barplot(data=prop_trends, x='CITY', y='PROPERTY_ADDRESS', hue='PROPERTY_TYPE', palette='Set2')
plt.title('Top Property Type Trends by City')
plt.xlabel('City')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Property Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ## 4.min and max prices of diff property sizes in diff cities

# %%
min_max_proptype=df.groupby(["CITY","SIZE"])["PRICE"].agg(["min","max"])
min_max_proptype
# Out:
#                     min      max
# CITY      SIZE
# Bangalore 1      0.2698   0.7792
#           2      0.2500   1.0200
#           3      0.0599   8.9300
#           4      1.2200   8.1000
#           5      1.2000   1.2000
#           6      5.5000   5.5000
# Chennai   1      0.4800   0.6183
#           2      0.2200   1.7800
#           3      0.4455   3.4800
#           4      0.9503   1.8700
#           5      2.1900   2.3600
#           6      6.0000   6.0000
# Delhi     1      0.1968   0.2868
#           2      0.2000   1.6000
#           3      0.3500  25.5600
#           4      0.6751  99.8900
#           5      3.6800  97.9400
#           6      2.5000   5.6000
#           8     29.0000  29.0000
# Hyderabad 2      0.3561   1.4400
#           3      0.7373   4.0700
#           4      1.5200   5.3700
#           5      1.7000   7.5200
# Mumbai    1      0.2000   3.5000
#           2      0.4300   4.7500
#           3      1.0400  21.8400
#           4      1.4600  18.7300
# ...

# %% [markdown]
# ## 5.Analysis on Rate per sqft in Hyderabad City based on their  Addresses

# %%
#HYDERABAD

df_hyd=df[(df["CITY"]=="Hyderabad") & (df["RATE_SQFT"]) ]
df_hyd.reset_index(inplace=True)

# %%
df_hyd
# Out:
#      index                                          BUILDERS  SIZE  \
# 0        0     Ashoka Builders India Private LimitedBUILDER0     3
# 1        2  Raghuram Pradeep Constructions India LLPBUILDER0     4
# 2        4                          Risinia BuildersBUILDER0     2
# 3        7                            Praneeth GroupBUILDER0     3
# 4        8                                         GHR Infra     3
# ..     ...                                               ...   ...
# 169    365                                 Salarpuria Sattva     4
# 170    366                                 Salarpuria Sattva     5
# 171    367                                 Salarpuria Sattva     5
# 172    368                                 Salarpuria Sattva     4
# 173    369                                 Salarpuria Sattva     4
#
#     PROPERTY_TYPE PROPERTY_ADDRESS       CITY  AREA  RATE_SQFT   PRICE  \
# 0       Apartment     Nanakramguda  Hyderabad  1870       9499  1.7700
# ...

# %%
df1=df_hyd[["CITY","RATE_SQFT","PROPERTY_ADDRESS"]]
df1
# Out:
#           CITY  RATE_SQFT PROPERTY_ADDRESS
# 0    Hyderabad       9499     Nanakramguda
# 1    Hyderabad      10891      Puppalaguda
# 2    Hyderabad       5599         Pragathi
# 3    Hyderabad       7599            Hyder
# 4    Hyderabad       5999           Kollur
# ..         ...        ...              ...
# 169  Hyderabad      12353          Kokapet
# 170  Hyderabad      13757          Kokapet
# 171  Hyderabad      13757          Kokapet
# 172  Hyderabad      12841          Kokapet
# 173  Hyderabad      12841          Kokapet
#
# [174 rows x 3 columns]

# %%
df1.describe()
# Out:
#           RATE_SQFT
# count    174.000000
# mean    7848.356322
# std     2361.985498
# min     4999.000000
# 25%     5999.000000
# 50%     7599.000000
# 75%     8004.500000
# max    13757.000000

# %%
low=df1[df1["RATE_SQFT"]<6000]
med=df1[(df1["RATE_SQFT"]>6000) & (df1["RATE_SQFT"]<9000)]
high=df1[(df1["RATE_SQFT"]>9000)]

# %%
sns.barplot(x=low["PROPERTY_ADDRESS"], y=low["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG LOW RATE_PER_SQUARE FEET AREAS IN HYD",color="r")
plt.show()

# %%
df_med=med.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_med
# Out:
# PROPERTY_ADDRESS
# Attapur             7499.000000
# Hyder               7599.000000
# Kompally            6751.000000
# Kukatpally          8399.000000
# Manchirevula        8000.034483
# Narsingi            8299.000000
# Nizampet            6001.000000
# Ramachandrapuram    7999.000000
# Tellapur            7299.000000
# Name: RATE_SQFT, dtype: float64

# %%
sns.barplot(x=med["PROPERTY_ADDRESS"], y=med["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG MEDIUM RATE_PER_SQUARE FEET AREAS IN HYD",color="r")
plt.show()

# %%
df_high=high.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_high
# Out:
# PROPERTY_ADDRESS
# Kokapet         13005.800000
# Kollur          10891.000000
# Kondapur        11868.733333
# Nanakramguda     9612.000000
# Puppalaguda     10396.000000
# Name: RATE_SQFT, dtype: float64

# %%
sns.barplot(x=high["PROPERTY_ADDRESS"], y=high["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG HIGH RATE_PER_SQUARE FEET AREAS IN HYD",color="r")
plt.show()

# %%
df["CITY"].unique()
# Out:
# array(['Hyderabad', 'Mumbai', 'Bangalore', 'Delhi', 'Chennai'],
#       dtype=object)

# %%
df_mum=df[(df["CITY"]=="Mumbai") & (df["RATE_SQFT"])]
df_mum.reset_index(inplace=True)
df_mum
# Out:
#      index              BUILDERS  SIZE PROPERTY_TYPE PROPERTY_ADDRESS    CITY  \
# 0      392  Homes treasvreAGENT4     2     Apartment          Andheri  Mumbai
# 1      399         ProptigerCity     2     Apartment            Thane  Mumbai
# 2      403         ProptigerCity     3     Apartment            Thane  Mumbai
# 3      404         ProptigerCity     2     Apartment            Thane  Mumbai
# 4      405         ProptigerCity     2     Apartment            Thane  Mumbai
# ..     ...                   ...   ...           ...              ...     ...
# 133    783             Proptiger     2     Apartment       Kanjurmarg  Mumbai
# 134    784             Proptiger     2     Apartment       Kanjurmarg  Mumbai
# 135    785             Proptiger     2     Apartment       Kanjurmarg  Mumbai
# 136    786             Proptiger     2     Apartment       Kanjurmarg  Mumbai
# 137    788                  amit     1     Apartment        Ghatkopar  Mumbai
#
# ...

# %%
df2=df_mum[["CITY","RATE_SQFT","PROPERTY_ADDRESS",]]
df2
# Out:
#        CITY  RATE_SQFT PROPERTY_ADDRESS
# 0    Mumbai       5555          Andheri
# 1    Mumbai      14615            Thane
# 2    Mumbai      14413            Thane
# 3    Mumbai      14409            Thane
# 4    Mumbai      14307            Thane
# ..      ...        ...              ...
# 133  Mumbai      18627       Kanjurmarg
# 134  Mumbai      19935       Kanjurmarg
# 135  Mumbai      20569       Kanjurmarg
# 136  Mumbai      18627       Kanjurmarg
# 137  Mumbai      24183        Ghatkopar
#
# [138 rows x 3 columns]

# %%
low2=df2[df2["RATE_SQFT"]<6000]
med2=df2[(df2["RATE_SQFT"]>6000) & (df2["RATE_SQFT"]<9000)]
high2=df2[(df2["RATE_SQFT"]>9000)]
df_low2=low2.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_low2

sns.barplot(x=low2["PROPERTY_ADDRESS"], y=low2["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG LOW RATE_PER_SQUARE FEET AREAS IN MUMBAI",color="r")
plt.show()

df_med2=med2.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_med2
sns.barplot(x=med2["PROPERTY_ADDRESS"], y=med2["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG MEDIUM RATE_PER_SQUARE FEET AREAS IN MUMBAI",color="r")
plt.show()

df_high2=high2.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_high2
sns.barplot(x=high2["PROPERTY_ADDRESS"], y=high2["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG HIGH RATE_PER_SQUARE FEET AREAS IN MUMBAI",color="r")
plt.show()

# %%
df_bang=df[(df["CITY"]=="Bangalore") & (df["RATE_SQFT"])]
df_bang.reset_index(inplace=True)
df_bang
# Out:
#     index                               BUILDERS  SIZE PROPERTY_TYPE  \
# 0     790                          ProptigerCity     2     Apartment
# 1     794                          ProptigerCity     2     Apartment
# 2     795                          ProptigerCity     2     Apartment
# 3     797                          ProptigerCity     2     Apartment
# 4     807                             Prop Urban     1     Apartment
# ..    ...                                    ...   ...           ...
# 83   1059                              Proptiger     2     Apartment
# 84   1073  Epcot Downtown Ventures pvt ltdAGENT0     3     Apartment
# 85   1074  Epcot Downtown Ventures pvt ltdAGENT0     3     Apartment
# 86   1077  Epcot Downtown Ventures pvt ltdAGENT0     2     Apartment
# 87   1079                      pavanraghBUILDER0     2     Apartment
#
#    PROPERTY_ADDRESS       CITY  AREA  RATE_SQFT   PRICE CONSTRUCTION_STATUS  \
# ...

# %%
df3=df_bang[["CITY","RATE_SQFT","PROPERTY_ADDRESS"]]
df3
# Out:
#          CITY  RATE_SQFT PROPERTY_ADDRESS
# 0   Bangalore       5495           Hennur
# 1   Bangalore       5535           Hennur
# 2   Bangalore       5497           Hennur
# 3   Bangalore       5543           Hennur
# 4   Bangalore       5709      Dasarahalli
# ..        ...        ...              ...
# 83  Bangalore       6331           Kogilu
# 84  Bangalore       6227         Sarjapur
# 85  Bangalore       6227         Sarjapur
# 86  Bangalore       6609         Sarjapur
# 87  Bangalore       6337            Begur
#
# [88 rows x 3 columns]

# %%
low3=df3[df3["RATE_SQFT"]<6000]
med3=df3[(df3["RATE_SQFT"]>6000) & (df3["RATE_SQFT"]<9000)]
high3=df3[(df3["RATE_SQFT"]>9000)]
df_low3=low3.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_low3

sns.barplot(x=low3["PROPERTY_ADDRESS"], y=low3["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG LOW RATE_PER_SQUARE FEET AREAS IN BANGALORE",color="r")
plt.show()

df_med3=med3.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_med3
sns.barplot(x=med3["PROPERTY_ADDRESS"], y=med3["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG MEDIUM RATE_PER_SQUARE FEET AREAS IN BANGALORE",color="r")
plt.show()

df_high3=high3.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_high3
sns.barplot(x=high3["PROPERTY_ADDRESS"], y=high3["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG HIGH RATE_PER_SQUARE FEET AREAS IN BANGALORE",color="r")
plt.show()

# %%
#DELHI

df_del=df[(df["CITY"]=="Delhi") & (df["RATE_SQFT"])]
df_del.reset_index(inplace=True)
df_del
# Out:
#      index                     BUILDERS  SIZE PROPERTY_TYPE PROPERTY_ADDRESS  \
# 0     1093              kumarBUILDER4.7     3     Apartment          Chhawla
# 1     1097  DELHI INFRATECH LTDAGENT2.9     2     Apartment          Chhawla
# 2     1098  DELHI INFRATECH LTDAGENT2.9     1     Apartment          Chhawla
# 3     1108             Property Gallery     4   Independent            Neeti
# 4     1115   B Kumar and BrothersAGENT0     4   Independent           Sunder
# ..     ...                          ...   ...           ...              ...
# 150   1440          Jagdamba Associates     3   Independent           Rohini
# 151   1444          Jagdamba Associates     3   Independent           Rohini
# 152   1446          CHILLAR HOMESAGENT0     4   Independent           Sector
# 153   1452          Yogesh SharmaAGENT0     3     Apartment           Sector
# 154   1457   B Kumar and BrothersAGENT0     5   Independent         Ghitorni
#
# ...

# %%
df4=df_del[["CITY","RATE_SQFT","PROPERTY_ADDRESS"]]
df4
# Out:
#       CITY  RATE_SQFT PROPERTY_ADDRESS
# 0    Delhi       3441          Chhawla
# 1    Delhi       3749          Chhawla
# 2    Delhi       3749          Chhawla
# 3    Delhi      42857            Neeti
# 4    Delhi     135877           Sunder
# ..     ...        ...              ...
# 150  Delhi      12173           Rohini
# 151  Delhi      13217           Rohini
# 152  Delhi      13121           Sector
# 153  Delhi       8823           Sector
# 154  Delhi      24783         Ghitorni
#
# [155 rows x 3 columns]

# %%
low4=df4[df4["RATE_SQFT"]<6000]
med4=df4[(df4["RATE_SQFT"]>6000) & (df4["RATE_SQFT"]<9000)]
high4=df4[(df4["RATE_SQFT"]>9000)]

df_low4=low4.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_low4

sns.barplot(x=low4["PROPERTY_ADDRESS"], y=low4["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG LOW RATE_PER_SQUARE FEET AREAS IN DELHI",color="r")
plt.show()

df_med4=med4.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_med4
sns.barplot(x=med4["PROPERTY_ADDRESS"], y=med4["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG MEDIUM RATE_PER_SQUARE FEET AREAS IN DELHI",color="r")
plt.show()

df_high4=high4.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_high4
sns.barplot(x=high4["PROPERTY_ADDRESS"], y=high4["RATE_SQFT"])
plt.xticks(rotation=90)
plt.title("AVG HIGH RATE_PER_SQUARE FEET AREAS IN DELHI",color="r")
plt.show()

# %%
#CHENNAI
df_chen=df[(df["CITY"]=="Chennai") & (df["RATE_SQFT"])]
df_chen.reset_index(inplace=True)
df_chen
# Out:
#      index                           BUILDERS  SIZE PROPERTY_TYPE  \
# 0     1507                          Proptiger     2     Apartment
# 1     1508                          Proptiger     2     Apartment
# 2     1509                          Proptiger     2     Apartment
# 3     1510                          Proptiger     2     Apartment
# 4     1511          Dee Star PropertiesAGENT0     3     Apartment
# ..     ...                                ...   ...           ...
# 101   1768  Full Basket property services Pvt     1     Apartment
# 102   1771  Full Basket property services Pvt     2     Apartment
# 103   1772  Full Basket property services Pvt     2     Apartment
# 104   1775  Full Basket property services Pvt     2     Apartment
# 105   1776  Full Basket property services Pvt     2     Apartment
#
#     PROPERTY_ADDRESS     CITY  AREA  RATE_SQFT   PRICE CONSTRUCTION_STATUS  \
# 0           Kanathur  Chennai   600       4749  0.2849       Ready to move
# ...

# %%
df5=df_chen[["CITY","RATE_SQFT","PROPERTY_ADDRESS"]]
df5
# Out:
#         CITY  RATE_SQFT PROPERTY_ADDRESS
# 0    Chennai       4749         Kanathur
# 1    Chennai       4749         Kanathur
# 2    Chennai       4299         Kanathur
# 3    Chennai       4299         Kanathur
# 4    Chennai       6647            Porur
# ..       ...        ...              ...
# 101  Chennai      12917   Sholinganallur
# 102  Chennai      11277   Sholinganallur
# 103  Chennai      11277   Sholinganallur
# 104  Chennai      10501   Sholinganallur
# 105  Chennai      10501   Sholinganallur
#
# [106 rows x 3 columns]

# %%
low5=df5[df5["RATE_SQFT"]<6000]
med5=df5[(df5["RATE_SQFT"]>6000) & (df5["RATE_SQFT"]<9000)]
high5=df5[(df5["RATE_SQFT"]>9000)]

df_low5=low5.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_low4

sns.barplot(x=low5["PROPERTY_ADDRESS"], y=low5["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG LOW RATE_PER_SQUARE FEET AREAS IN CHENNAI",color="r")
plt.show()

df_med5=med5.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_med5
sns.barplot(x=med5["PROPERTY_ADDRESS"], y=med5["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG MEDIUM RATE_PER_SQUARE FEET AREAS IN CHENNAI",color="r")
plt.show()

df_high5=high5.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_high5
sns.barplot(x=high5["PROPERTY_ADDRESS"], y=high5["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG HIGH RATE_PER_SQUARE FEET AREAS IN CHENNAI",color="r")
plt.show()

# %%
low5=df5[df5["RATE_SQFT"]<6000]
med5=df5[(df5["RATE_SQFT"]>6000) & (df5["RATE_SQFT"]<9000)]
high5=df5[(df5["RATE_SQFT"]>9000)]

df_low5=low5.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_low4

sns.barplot(x=low5["PROPERTY_ADDRESS"], y=low5["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG LOW RATE_PER_SQUARE FEET AREAS IN CHENNAI",color="r")
plt.show()

df_med5=med5.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_med5
sns.barplot(x=med5["PROPERTY_ADDRESS"], y=med5["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG MEDIUM RATE_PER_SQUARE FEET AREAS IN CHENNAI",color="r")
plt.show()

df_high5=high5.groupby(["PROPERTY_ADDRESS"])["RATE_SQFT"].mean()
df_high5
sns.barplot(x=high5["PROPERTY_ADDRESS"], y=high5["RATE_SQFT"])
plt.xticks(rotation=45)
plt.title("AVG HIGH RATE_PER_SQUARE FEET AREAS IN CHENNAI",color="r")
plt.show()

# %% [markdown]
# ### 6.Analysis on distribution of property sizes in Hyderabad City based on their  Addresses

# %%
df_hyd
# Out:
#      index                                          BUILDERS  SIZE  \
# 0        0     Ashoka Builders India Private LimitedBUILDER0     3
# 1        2  Raghuram Pradeep Constructions India LLPBUILDER0     4
# 2        4                          Risinia BuildersBUILDER0     2
# 3        7                            Praneeth GroupBUILDER0     3
# 4        8                                         GHR Infra     3
# ..     ...                                               ...   ...
# 169    365                                 Salarpuria Sattva     4
# 170    366                                 Salarpuria Sattva     5
# 171    367                                 Salarpuria Sattva     5
# 172    368                                 Salarpuria Sattva     4
# 173    369                                 Salarpuria Sattva     4
#
#     PROPERTY_TYPE PROPERTY_ADDRESS       CITY  AREA  RATE_SQFT   PRICE  \
# 0       Apartment     Nanakramguda  Hyderabad  1870       9499  1.7700
# ...

# %%
# hyd sizes
data_hyd= df_hyd.groupby('PROPERTY_ADDRESS')['SIZE'].value_counts().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
data_hyd.plot(kind='bar', stacked=True, ax=plt.gca(), width=0.8)
plt.title('DISTRIBUTION OF PROPERTY TYPES BASED ON SIZES IN HYDERABAD')
plt.xlabel('PROPERTY_ADDRESS')
plt.ylabel('FREQUENCY')
plt.xticks(rotation=45)  
plt.legend(title='SIZE')
plt.show()

# %%
#mumbai sizes
data_mum= df_mum.groupby('PROPERTY_ADDRESS')['SIZE'].value_counts().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
data_mum.plot(kind='bar', stacked=True, ax=plt.gca(), width=0.8)
plt.title('DISTRIBUTION OF PROPERTY TYPES BASED ON SIZES IN MUMBAI')
plt.xlabel('PROPERTY_ADDRESS')
plt.ylabel('FREQUENCY')
plt.xticks(rotation=45)  
plt.legend(title='SIZE')
plt.show()

# %%
# Banglore sizes
data_bang= df_bang.groupby('PROPERTY_ADDRESS')['SIZE'].value_counts().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
data_bang.plot(kind='bar', stacked=True, ax=plt.gca(), width=0.8)
plt.title('DISTRIBUTION OF PROPERTY TYPES BASED ON SIZES IN BANGALORE')
plt.xlabel('PROPERTY_ADDRESS')
plt.ylabel('FREQUENCY')
plt.xticks(rotation=45)  
plt.legend(title='SIZE')
plt.show()

# %%
# Delhi sizes
data_del= df_del.groupby('PROPERTY_ADDRESS')['SIZE'].value_counts().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
data_del.plot(kind='bar', stacked=True, ax=plt.gca(), width=0.8)
plt.title('DISTRIBUTION OF PROPERTY TYPES BASED ON SIZES IN DELHI')
plt.xlabel('PROPERTY_ADDRESS')
plt.ylabel('FREQUENCY')
plt.xticks(rotation=45)  
plt.legend(title='SIZE')
plt.show()

# %%
#Chennai sizes
data_chen= df_chen.groupby('PROPERTY_ADDRESS')['SIZE'].value_counts().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
data_chen.plot(kind='bar', stacked=True, ax=plt.gca(), width=0.8)
plt.title('DISTRIBUTION OF PROPERTY TYPES BASED ON SIZES IN CHENNAI')
plt.xlabel('PROPERTY_ADDRESS')
plt.ylabel('FREQUENCY')
plt.xticks(rotation=45)  
plt.legend(title='SIZE')
plt.show()

# %%
df_hyd[0:2]
# Out:
#    index                                          BUILDERS  SIZE  \
# 0      0     Ashoka Builders India Private LimitedBUILDER0     3
# 1      2  Raghuram Pradeep Constructions India LLPBUILDER0     4
#
#   PROPERTY_TYPE PROPERTY_ADDRESS       CITY  AREA  RATE_SQFT  PRICE  \
# 0     Apartment     Nanakramguda  Hyderabad  1870       9499   1.77
# 1     Apartment      Puppalaguda  Hyderabad  3715      10891   4.04
#
#   CONSTRUCTION_STATUS LISTED_BY
# 0  Under Construction   BUILDER
# 1  Under Construction   BUILDER

# %%
df_hyd[["PROPERTY_TYPE","PROPERTY_ADDRESS"]]
# Out:
#     PROPERTY_TYPE PROPERTY_ADDRESS
# 0       Apartment     Nanakramguda
# 1       Apartment      Puppalaguda
# 2       Apartment         Pragathi
# 3       Apartment            Hyder
# 4       Apartment           Kollur
# ..            ...              ...
# 169     Apartment          Kokapet
# 170     Apartment          Kokapet
# 171     Apartment          Kokapet
# 172     Apartment          Kokapet
# 173     Apartment          Kokapet
#
# [174 rows x 2 columns]

# %%
grouped =df_hyd.groupby(["PROPERTY_ADDRESS"])["PROPERTY_TYPE"].value_counts()

# %%
grouped
# Out:
# PROPERTY_ADDRESS  PROPERTY_TYPE
# Attapur           Apartment         6
# Bachupally        Apartment        13
# Hyder             Apartment        15
# Kokapet           Apartment        10
# Kollur            Apartment        13
#                   Villa             4
# Kompally          Apartment         1
# Kondapur          Apartment        15
# Kukatpally        Apartment         3
# Manchirevula      Apartment        29
# Nanakramguda      Apartment         8
# Narsingi          Apartment         1
# Nizampet          Apartment         1
# Patighanpur       Apartment         2
# Pocharam          Apartment        24
# Pragathi          Apartment         4
# Puppalaguda       Apartment         2
# Ramachandrapuram  Villa             3
# Tellapur          Apartment        16
#                   Independent       3
# Yapral            Apartment         1
# Name: count, dtype: int64
